# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
# Here I am cheking for nulls to understand what columsn need to be updated
missing_values = data.isnull().sum()
missing_values
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
#I use this to see all columns
data.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'car', 'Bar', 'CoffeeHouse',
#        'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50',
#        'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp', 'Y'],
#       dtype='object')

# %%
data.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# Here we can look the unique values of the problematic columns
car = data['car'].unique()
print(car)
Bar  = data['Bar'].unique()  
print(Bar)
CoffeeHouse= data['CoffeeHouse'].unique()
print(CoffeeHouse)
CarryAway= data['CarryAway'].unique() 
print(CarryAway)
RestaurantLessThan20= data['RestaurantLessThan20'].unique() 
print(RestaurantLessThan20)
Restaurant20To50= data['Restaurant20To50'].unique() 
print(Restaurant20To50)

#Given that Most of the car Records are null the coulumn will be dropped from the Database. 
data=data.drop('car', axis=1)
data.columns
# Out:
# [nan 'Scooter and motorcycle' 'crossover' 'Mazda5' 'do not drive'
#  'Car that is too old to install Onstar :D']
# ['never' 'less1' '1~3' 'gt8' nan '4~8']
# ['never' 'less1' '4~8' '1~3' 'gt8' nan]
# [nan '4~8' '1~3' 'gt8' 'less1' 'never']
# ['4~8' '1~3' 'less1' 'gt8' nan 'never']
# ['1~3' 'less1' 'never' 'gt8' '4~8' nan]
# Index(['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway',
#        'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min',
#        'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same',
#        'direction_opp', 'Y'],
#       dtype='object')

# %%
#Checking in different cases if Null exist in multiple columns
#data[data['CoffeeHouse'].isnull()].isnull().sum()
#data[data['Restaurant20To50'].isnull()].isnull().sum()
# given that when nulls exist the nulls are in more than one column, and given that the number of null rows is not material we will drop all Nulls from the data
df=data.dropna(axis=0, inplace=False)
df.head(5)
# Out:
#         destination  passanger weather  temperature  time  \
# 22  No Urgent Place      Alone   Sunny           55   2PM
# 23  No Urgent Place  Friend(s)   Sunny           80  10AM
# 24  No Urgent Place  Friend(s)   Sunny           80  10AM
# 25  No Urgent Place  Friend(s)   Sunny           80  10AM
# 26  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                    coupon expiration gender age maritalStatus  ...  \
# 22        Restaurant(<20)         1d   Male  21        Single  ...
# 23           Coffee House         2h   Male  21        Single  ...
# 24                    Bar         1d   Male  21        Single  ...
# 25  Carry out & Take away         2h   Male  21        Single  ...
# 26           Coffee House         1d   Male  21        Single  ...
#
#     CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 22        less1       4~8                  4~8            less1
# 23        less1       4~8                  4~8            less1
# ...

# %%
#The following is to show the data has no Nulls now
missing_values=df.isnull().sum()
missing_values
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# dtype: int64

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
df['Y'].sum()/df['Y'].count()

print(" The proportion of the total observations chose to accept the coupon is:" )
print( df['Y'].sum()/df['Y'].count())
# Out:
#  The proportion of the total observations chose to accept the coupon is:
# 0.5693352098683666

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
# The barplot shows the mean of acceptance
sns.barplot(data=df, x='coupon', y='Y')
plt.xticks(rotation=90)
plt.show()
# For further understading I include a countplot as well. 
sns.countplot(x='coupon', data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.histplot(data=df, x='temperature', bins=10)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.title('Temperature Distribution')
plt.show()

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_df=df[df['coupon']=='Bar']
bar_df.head(5)
# Out:
#         destination  passanger weather  temperature  time coupon expiration  \
# 24  No Urgent Place  Friend(s)   Sunny           80  10AM    Bar         1d
# 35             Home      Alone   Sunny           55   6PM    Bar         1d
# 39             Work      Alone   Sunny           55   7AM    Bar         1d
# 46  No Urgent Place  Friend(s)   Sunny           80  10AM    Bar         1d
# 57             Home      Alone   Sunny           55   6PM    Bar         1d
#
#    gender age maritalStatus  ...  CoffeeHouse CarryAway RestaurantLessThan20  \
# 24   Male  21        Single  ...        less1       4~8                  4~8
# 35   Male  21        Single  ...        less1       4~8                  4~8
# 39   Male  21        Single  ...        less1       4~8                  4~8
# 46   Male  46        Single  ...          4~8       1~3                  1~3
# 57   Male  46        Single  ...          4~8       1~3                  1~3
#
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
print('Proportion of bar coupons that were accepted:')
bar_df['Y'].sum()/bar_df['Y'].count()
# Out:
# Proportion of bar coupons that were accepted:
# 0.41191845269210664

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
fewer_than_3 = bar_df[bar_df['Bar'].isin(['less1', '1~3', 'never'])]['Y'].sum()
more_than_3= bar_df[~bar_df['Bar'].isin(['less1', '1~3', 'never'])]['Y'].sum()

print('acceptance rate between those who went to a bar 3 or fewer times')
print(fewer_than_3/bar_df['Y'].count())
print('acceptance rate between those who went to a more than 3 times')
print(more_than_3/bar_df['Y'].count())
# Out:
# acceptance rate between those who went to a bar 3 or fewer times
# 0.3350757971772086
# acceptance rate between those who went to a more than 3 times
# 0.07684265551489806

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
more_than_1_over_25_accepted=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['age'].isin(['21', 'below21']))]['Y'].sum()
more_than_1_over_25_all=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['age'].isin(['21', 'below21']))]['Y'].count()

print('Acceptance of those who go to a bar more than once a month and are over the age of 25:')
print(more_than_1_over_25_accepted/more_than_1_over_25_all)

print('Others:')
less_than_1_accepted= more_than_3= bar_df[(bar_df['Bar'].isin(['less1', 'never']))]['Y'].sum()
less_than_1_all= more_than_3= bar_df[(bar_df['Bar'].isin(['less1', 'never'])) ]['Y'].count()

print(less_than_1_accepted/less_than_1_all)
# Out:
# Acceptance of those who go to a bar more than once a month and are over the age of 25:
# 0.6898263027295285
# Others:
# 0.2953020134228188

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
more_than_1_notkid_not_fff=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['passanger'].isin(['Kid(s)']))&(~bar_df['occupation'].isin(['Farming Fishing & Forestry']))]['Y'].count()
more_than_1_notkid_not_fff_accepted=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['passanger'].isin(['Kid(s)']))&(~bar_df['occupation'].isin(['Farming Fishing & Forestry']))]['Y'].sum()
print('Acceptance of  drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry')
print(more_than_1_notkid_not_fff_accepted/more_than_1_notkid_not_fff)
# Out:
# Acceptance of  drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry
# 0.7094339622641509

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
#go to bars more than once a month, had passengers that were not a kid, and were not widowed
more_than_1_notkid_not_widowed=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['passanger'].isin(['Kid(s)']))&(~bar_df['maritalStatus'].isin(['Widowed']))]['Y'].count()
more_than_1_notkid_not_widowed_accepted=  bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (~bar_df['passanger'].isin(['Kid(s)']))&(~bar_df['maritalStatus'].isin(['Widowed']))]['Y'].sum()
print('Acceptance of drivers that go to bars more than once a month, had passengers that were not a kid, and were not widowed')
print(more_than_1_notkid_not_widowed_accepted/more_than_1_notkid_not_widowed)

#go to bars more than once a month and are under the age of 30
more_than_1_under_30= bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (bar_df['age'].isin(['21','26','below21']))]['Y'].count()
more_than_1_under_30_accepted= bar_df[(~bar_df['Bar'].isin(['less1', 'never'])) & (bar_df['age'].isin(['21','26','below21']))]['Y'].sum()
print('Acceptance of drivers that go to bars more than once a month and are under the age of 30')
print(more_than_1_under_30_accepted/more_than_1_under_30)

#go to cheap restaurants more than 4 times a month and income is less than 50K
cheap_res4times_under_50k=bar_df[(bar_df['RestaurantLessThan20'].isin(['4~8', 'gt8'])) & (bar_df['income'].isin(['Less than $12500','$12500 - $24999','$25000 - $37499','$37500 - $49999']))]['Y'].count()
cheap_res4times_under_50k_accepted=bar_df[(bar_df['RestaurantLessThan20'].isin(['4~8', 'gt8'])) & (bar_df['income'].isin(['Less than $12500','$12500 - $24999','$25000 - $37499','$37500 - $49999']))]['Y'].sum()
print('Acceptance of drivers that to cheap restaurants more than 4 times a month and income is less than 50K')
print(cheap_res4times_under_50k_accepted/cheap_res4times_under_50k)
# Out:
# Acceptance of drivers that go to bars more than once a month, had passengers that were not a kid, and were not widowed
# 0.7094339622641509
# Acceptance of drivers that go to bars more than once a month and are under the age of 30
# 0.7195121951219512
# Acceptance of drivers that to cheap restaurants more than 4 times a month and income is less than 50K
# 0.45645645645645644

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# The likelihood of driver accepting the coupon increase when they are under 30 years old and go to bar more than once per month

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %%
# Filtering the dataframe to only show coupons with coffee house data
coffee_df=df[df['coupon']=='Coffee House']
coffee_df.head(5)
# Out:
#         destination  passanger weather  temperature  time        coupon  \
# 23  No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 26  No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 27  No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 28  No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 30  No Urgent Place  Friend(s)   Sunny           80   6PM  Coffee House
#
#    expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 23         2h   Male  21        Single  ...        less1       4~8
# 26         1d   Male  21        Single  ...        less1       4~8
# 27         2h   Male  21        Single  ...        less1       4~8
# 28         1d   Male  21        Single  ...        less1       4~8
# 30         2h   Male  21        Single  ...        less1       4~8
#
#    RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
# In order to analize  how all varaibles affect acceptance in a quick and  simple way I will use barplots for all columns
import textwrap

# Define the columns for plotting
columns = ['destination', 'passanger', 'weather', 'temperature', 'time', 'coupon', 'expiration', 'gender', 'age', 'maritalStatus', 'has_children', 'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same', 'direction_opp']

# Calculate the number of rows and columns for the subplots grid
num_plots = len(columns)
num_rows = (num_plots + 2) // 3  # Add 2 to ensure enough space for the last row
num_cols = min(num_plots, 3)

# Adjust the size of each inner plot
inner_plot_size = 6  # Modify this value to adjust the size of each inner plot
figsize = (num_cols * inner_plot_size, num_rows * inner_plot_size)  # Calculate the figure size based on the number of rows and columns

# Create the subplots grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)

# Add spacing between subplots
plt.subplots_adjust(hspace=1, wspace=0.5) 

# Flatten the axes array to iterate over each subplot
axes = axes.flatten()

# Iterate over the columns and create the barplot for each column
for i, column in enumerate(columns):
    ax = axes[i]  # Select the current subplot
    sns.barplot(x=column, y='Y', data=coffee_df, ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel('Acceptance Rate (Y)')
    title = f'Barplot: Acceptance Rate (Y) for Coffee House Coupons\n{column}'
    wrapped_title = "\n".join(textwrap.wrap(title, width=20))  # Adjust the width as needed
    ax.set_title(wrapped_title)   

    ax.tick_params(axis='x', rotation=90)

# Hide the empty subplots, if any
if num_plots < len(axes):
    for j in range(num_plots, len(axes)):
        axes[j].axis('off')

# Show the plot
plt.show()

# %%
rest_df=df[df['coupon']=='Restaurant(<20)']
rest_df.head(5)
# Out:
#         destination  passanger weather  temperature time           coupon  \
# 22  No Urgent Place      Alone   Sunny           55  2PM  Restaurant(<20)
# 29  No Urgent Place  Friend(s)   Sunny           80  2PM  Restaurant(<20)
# 31  No Urgent Place  Friend(s)   Sunny           80  6PM  Restaurant(<20)
# 42             Work      Alone   Sunny           55  7AM  Restaurant(<20)
# 44  No Urgent Place      Alone   Sunny           55  2PM  Restaurant(<20)
#
#    expiration gender age maritalStatus  ...  CoffeeHouse CarryAway  \
# 22         1d   Male  21        Single  ...        less1       4~8
# 29         1d   Male  21        Single  ...        less1       4~8
# 31         2h   Male  21        Single  ...        less1       4~8
# 42         1d   Male  21        Single  ...        less1       4~8
# 44         1d   Male  46        Single  ...          4~8       1~3
#
#    RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
# This is the sane analysis as above but for the Restaurants under 20
import textwrap

# Define the columns for plotting
columns = ['destination', 'passanger', 'weather', 'temperature', 'time', 'expiration', 'gender', 'age', 'maritalStatus', 'has_children', 'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same', 'direction_opp']

# Calculate the number of rows and columns for the subplots grid
num_plots = len(columns)
num_rows = (num_plots + 2) // 3  # Add 2 to ensure enough space for the last row
num_cols = min(num_plots, 3)

# Adjust the size of each inner plot
inner_plot_size = 6  # Modify this value to adjust the size of each inner plot
figsize = (num_cols * inner_plot_size, num_rows * inner_plot_size)  # Calculate the figure size based on the number of rows and columns

# Create the subplots grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)

# Add spacing between subplots
plt.subplots_adjust(hspace=1, wspace=0.5) 

# Flatten the axes array to iterate over each subplot
axes = axes.flatten()

# Iterate over the columns and create the barplot for each column
for i, column in enumerate(columns):
    ax = axes[i]  # Select the current subplot
    sns.barplot(x=column, y='Y', data=rest_df, ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel('Acceptance Rate (Y)')
    title = f'Barplot: Acceptance Rate (Y) for Rest Under 20 Coupons\n{column}'
    wrapped_title = "\n".join(textwrap.wrap(title, width=20))  # Adjust the width as needed
    ax.set_title(wrapped_title)   

    ax.tick_params(axis='x', rotation=90)

# Hide the empty subplots, if any
if num_plots < len(axes):
    for j in range(num_plots, len(axes)):
        axes[j].axis('off')

# Show the plot
plt.show()

# %%
# This is the sane analysis as above but for the Bar Coupons
import textwrap

# Define the columns for plotting
columns = ['destination', 'passanger', 'weather', 'temperature', 'time', 'expiration', 'gender', 'age', 'maritalStatus', 'has_children', 'education', 'occupation', 'income', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min', 'direction_same', 'direction_opp']

# Calculate the number of rows and columns for the subplots grid
num_plots = len(columns)
num_rows = (num_plots + 2) // 3  # Add 2 to ensure enough space for the last row
num_cols = min(num_plots, 3)

# Adjust the size of each inner plot
inner_plot_size = 6  # Modify this value to adjust the size of each inner plot
figsize = (num_cols * inner_plot_size, num_rows * inner_plot_size)  # Calculate the figure size based on the number of rows and columns

# Create the subplots grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)

# Add spacing between subplots
plt.subplots_adjust(hspace=1, wspace=0.5) 

# Flatten the axes array to iterate over each subplot
axes = axes.flatten()

# Iterate over the columns and create the barplot for each column
for i, column in enumerate(columns):
    ax = axes[i]  # Select the current subplot
    sns.barplot(x=column, y='Y', data=bar_df, ax=ax)
    ax.set_xlabel(column)
    ax.set_ylabel('Acceptance Rate (Y)')
    title = f'Barplot: Acceptance Rate (Y) for Bar Coupons\n{column}'
    wrapped_title = "\n".join(textwrap.wrap(title, width=20))  # Adjust the width as needed
    ax.set_title(wrapped_title)   

    ax.tick_params(axis='x', rotation=90)

# Hide the empty subplots, if any
if num_plots < len(axes):
    for j in range(num_plots, len(axes)):
        axes[j].axis('off')

# Show the plot
plt.show()
